# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

from tqdm import tqdm

import time

# %%
molecule = new_client.molecule

safe_drugs = molecule.filter(organism="Homo sapiens", assay_type="B", pchembl_value__gte=6, pchembl_value__lte=9, max_phase=4, known_drug=True, oral=True).only(["molecule_chembl_id", "pref_name", "molecule_structures"])
safe_drugs_df = pd.DataFrame(safe_drugs)
safe_drugs_df['canonical_smiles'] = safe_drugs_df.loc[ safe_drugs_df['molecule_structures'].notnull(),'molecule_structures'].apply(lambda x: x['canonical_smiles'])

safe_drugs_list = safe_drugs_df["molecule_chembl_id"].tolist()
len(safe_drugs_list)
# Out:
# 1923

# %%
safe_drugs_df
# Out:
#      molecule_chembl_id                                molecule_structures  \
# 0               CHEMBL2  {'canonical_smiles': 'COc1cc2nc(N3CCN(C(=O)c4c...
# 1               CHEMBL3  {'canonical_smiles': 'CN1CCC[C@H]1c1cccnc1', '...
# 2               CHEMBL4  {'canonical_smiles': 'CC1COc2c(N3CCN(C)CC3)c(F...
# 3               CHEMBL5  {'canonical_smiles': 'CCn1cc(C(=O)O)c(=O)c2ccc...
# 4               CHEMBL6  {'canonical_smiles': 'COc1ccc2c(c1)c(CC(=O)O)c...
# ...                 ...                                                ...
# 1918      CHEMBL5315120  {'canonical_smiles': 'CCCCC1(CCCC)CN(c2ccccc2)...
# 1919      CHEMBL5315121  {'canonical_smiles': 'O.O=C(NN1C(=O)[C@@H]2[C@...
# 1920      CHEMBL5315124  {'canonical_smiles': 'C[C@H]1COc2c(N3CCN(C)CC3...
# 1921      CHEMBL5315125  {'canonical_smiles': 'C[C@H](Nc1ncnc2nc[nH]c12...
# 1922      CHEMBL5465559                                               None
#
#                      pref_name  \
# 0                     PRAZOSIN
# 1                     NICOTINE
# 2                    OFLOXACIN
# 3               NALIDIXIC ACID
# 4                 INDOMETHACIN
# ...                        ...
# 1918  ODEVIXIBAT SESQUIHYDRATE
# 1919   TECOVIRIMAT MONOHYDRATE
# 1920              LEVOFLOXACIN
# 1921     DUVELISIB MONOHYDRATE
# 1922                  NYSTATIN
#
#                                        canonical_smiles
# 0         COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC
# 1                                  CN1CCC[C@H]1c1cccnc1
# 2      CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 3                       CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 4        COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1
# ...                                                 ...
# 1918  CCCCC1(CCCC)CN(c2ccccc2)c2cc(SC)c(OCC(=O)N[C@@...
# 1919  O.O=C(NN1C(=O)[C@@H]2[C@@H]3C=C[C@@H]([C@H]4C[...
# 1920  C[C@H]1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)...
# 1921  C[C@H](Nc1ncnc2nc[nH]c12)c1cc2cccc(Cl)c2c(=O)n...
# 1922                                                NaN
#
# [1923 rows x 4 columns]

# %%
def ChemblMOA(chembl_id):
    max_retries = 5
    retries = 0
    while retries < max_retries:
        try:
            activity = new_client.mechanism.filter(molecule_chembl_id=chembl_id)[0]
            activity_df = pd.DataFrame(activity)
            drop_col = ['binding_site_comment', 'mec_id', 'mechanism_comment', 'mechanism_refs', 'molecular_mechanism', 'record_id', 'selectivity_comment', 'site_id', 'variant_sequence']
            cols_to_drop = list(set(drop_col).intersection(activity_df.columns))
            activity_clean_df = activity_df.drop(cols_to_drop, axis=1)
            activity_final_df = activity_clean_df.drop_duplicates(subset="molecule_chembl_id", keep="first")
            return(activity_final_df)
        except:
            retries += 1
            time.sleep(1)
            return None

# %%
ChemblMOA("CHEMBL112")
# Out:
#   action_type  direct_interaction  disease_efficacy  max_phase  \
# 0   INHIBITOR                   1                 1          4
#
#         mechanism_of_action molecule_chembl_id parent_molecule_chembl_id  \
# 0  Cyclooxygenase inhibitor          CHEMBL112                 CHEMBL112
#
#   target_chembl_id
# 0    CHEMBL2094253

# %%
chembl_moa_list = []

for id in tqdm(safe_drugs_list, total = len(safe_drugs_list)):
    res = ChemblMOA(id)
    res2 = pd.DataFrame(res)
    chembl_moa_list.append(res2)
                
chembl_moa_df = pd.concat(chembl_moa_list, ignore_index=True)
# Out:
# 100%|███████████████████████████████████████| 1923/1923 [05:19<00:00,  6.02it/s]

# %%
len(chembl_moa_df)
# Out:
# 1425

# %%
chembl_moa_df = chembl_moa_df[chembl_moa_df["mechanism_of_action"].notna()]
len(chembl_moa_df)
# Out:
# 1425

# %%
chembl_moa_names_df = chembl_moa_df.merge(safe_drugs_df, on="molecule_chembl_id", how="left")
chembl_moa_names_df
# Out:
#              action_type  direct_interaction  disease_efficacy  max_phase  \
# 0                AGONIST                   1                 1          4
# 1              INHIBITOR                   1                 1          4
# 2              INHIBITOR                   1                 1          4
# 3              INHIBITOR                   1                 1          4
# 4              INHIBITOR                   1                 1          4
# ...                  ...                 ...               ...        ...
# 1420           INHIBITOR                   1                 1          4
# 1421           INHIBITOR                   1                 1          4
# 1422           INHIBITOR                   1                 1          4
# 1423           INHIBITOR                   1                 1          4
# 1424  SEQUESTERING AGENT                   1                 1          4
#
#                                     mechanism_of_action molecule_chembl_id  \
# 0     Neuronal acetylcholine receptor; alpha4/beta2 ...            CHEMBL3
# 1                        Bacterial DNA gyrase inhibitor            CHEMBL4
# 2                        Bacterial DNA gyrase inhibitor            CHEMBL5
# 3                              Cyclooxygenase inhibitor            CHEMBL6
# 4                        Bacterial DNA gyrase inhibitor            CHEMBL8
# ...                                                 ...                ...
# 1420              Ileal bile acid transporter inhibitor      CHEMBL5315120
# 1421            Envelope phospholipase OPG057 inhibitor      CHEMBL5315121
# 1422                               DNA gyrase inhibitor      CHEMBL5315124
# 1423            PI3-kinase p110-delta subunit inhibitor      CHEMBL5315125
# 1424                      Ergosterol sequestering agent      CHEMBL5465559
#
#      parent_molecule_chembl_id target_chembl_id  \
# 0                      CHEMBL3    CHEMBL1907589
# 1                      CHEMBL4    CHEMBL2311224
# 2                      CHEMBL5    CHEMBL2311224
# 3                      CHEMBL6    CHEMBL2094253
# 4                      CHEMBL8    CHEMBL2311224
# ...                        ...              ...
# 1420             CHEMBL4297588       CHEMBL2778
# 1421             CHEMBL1257073    CHEMBL5308522
# 1422                  CHEMBL33    CHEMBL2311225
# 1423             CHEMBL3039502       CHEMBL3130
# 1424             CHEMBL5465559    CHEMBL2364028
#
#                                     molecule_structures  \
# 0     {'canonical_smiles': 'CN1CCC[C@H]1c1cccnc1', '...
# 1     {'canonical_smiles': 'CC1COc2c(N3CCN(C)CC3)c(F...
# 2     {'canonical_smiles': 'CCn1cc(C(=O)O)c(=O)c2ccc...
# 3     {'canonical_smiles': 'COc1ccc2c(c1)c(CC(=O)O)c...
# 4     {'canonical_smiles': 'O=C(O)c1cn(C2CC2)c2cc(N3...
# ...                                                 ...
# 1420  {'canonical_smiles': 'CCCCC1(CCCC)CN(c2ccccc2)...
# 1421  {'canonical_smiles': 'O.O=C(NN1C(=O)[C@@H]2[C@...
# 1422  {'canonical_smiles': 'C[C@H]1COc2c(N3CCN(C)CC3...
# 1423  {'canonical_smiles': 'C[C@H](Nc1ncnc2nc[nH]c12...
# 1424                                               None
#
#                      pref_name  \
# 0                     NICOTINE
# 1                    OFLOXACIN
# 2               NALIDIXIC ACID
# 3                 INDOMETHACIN
# 4                CIPROFLOXACIN
# ...                        ...
# 1420  ODEVIXIBAT SESQUIHYDRATE
# 1421   TECOVIRIMAT MONOHYDRATE
# 1422              LEVOFLOXACIN
# 1423     DUVELISIB MONOHYDRATE
# 1424                  NYSTATIN
#
#                                        canonical_smiles
# 0                                  CN1CCC[C@H]1c1cccnc1
# 1      CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 2                       CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 3        COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1
# 4            O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O
# ...                                                 ...
# 1420  CCCCC1(CCCC)CN(c2ccccc2)c2cc(SC)c(OCC(=O)N[C@@...
# 1421  O.O=C(NN1C(=O)[C@@H]2[C@@H]3C=C[C@@H]([C@H]4C[...
# 1422  C[C@H]1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)...
# 1423  C[C@H](Nc1ncnc2nc[nH]c12)c1cc2cccc(Cl)c2c(=O)n...
# 1424                                                NaN
#
# [1425 rows x 11 columns]

# %%
mito_str_list = ["Mitochondria", "mitochondria"]

mito_moa = chembl_moa_names_df[chembl_moa_names_df["mechanism_of_action"].str.contains('|'.join(mito_str_list))]
mito_moa
# Out:
#                        action_type  direct_interaction  disease_efficacy  \
# 542                      INHIBITOR                   1                 1
# 591                      INHIBITOR                   1                 1
# 966  POSITIVE ALLOSTERIC MODULATOR                   1                 1
#
#      max_phase                                mechanism_of_action  \
# 542          4       DNA topoisomerase I, mitochondrial inhibitor
# 591          4  Mitochondrial complex I (NADH dehydrogenase) i...
# 966          4  Carbamoyl-phosphate synthase [ammonia], mitoch...
#
#     molecule_chembl_id parent_molecule_chembl_id target_chembl_id  \
# 542         CHEMBL1607                  CHEMBL84    CHEMBL2362989
# 591         CHEMBL1703                CHEMBL1431    CHEMBL2363065
# 966      CHEMBL1201780             CHEMBL1201780    CHEMBL2362990
#
#                                    molecule_structures  \
# 542  {'canonical_smiles': 'CC[C@@]1(O)C(=O)OCc2c1cc...
# 591  {'canonical_smiles': 'CN(C)C(=N)NC(=N)N.Cl', '...
# 966  {'canonical_smiles': 'NC(=O)N[C@@H](CCC(=O)O)C...
#
#                    pref_name  \
# 542  TOPOTECAN HYDROCHLORIDE
# 591  METFORMIN HYDROCHLORIDE
# 966           CARGLUMIC ACID
#
#                                       canonical_smiles
# 542  CC[C@@]1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C...
# 591                               CN(C)C(=N)NC(=N)N.Cl
# 966                      NC(=O)N[C@@H](CCC(=O)O)C(=O)O

# %%
mito_safe_drugs = chembl_moa_names_df[~chembl_moa_names_df["mechanism_of_action"].str.contains('|'.join(mito_str_list))]
mito_safe_drugs
# Out:
#              action_type  direct_interaction  disease_efficacy  max_phase  \
# 0                AGONIST                   1                 1          4
# 1              INHIBITOR                   1                 1          4
# 2              INHIBITOR                   1                 1          4
# 3              INHIBITOR                   1                 1          4
# 4              INHIBITOR                   1                 1          4
# ...                  ...                 ...               ...        ...
# 1420           INHIBITOR                   1                 1          4
# 1421           INHIBITOR                   1                 1          4
# 1422           INHIBITOR                   1                 1          4
# 1423           INHIBITOR                   1                 1          4
# 1424  SEQUESTERING AGENT                   1                 1          4
#
#                                     mechanism_of_action molecule_chembl_id  \
# 0     Neuronal acetylcholine receptor; alpha4/beta2 ...            CHEMBL3
# 1                        Bacterial DNA gyrase inhibitor            CHEMBL4
# 2                        Bacterial DNA gyrase inhibitor            CHEMBL5
# 3                              Cyclooxygenase inhibitor            CHEMBL6
# 4                        Bacterial DNA gyrase inhibitor            CHEMBL8
# ...                                                 ...                ...
# 1420              Ileal bile acid transporter inhibitor      CHEMBL5315120
# 1421            Envelope phospholipase OPG057 inhibitor      CHEMBL5315121
# 1422                               DNA gyrase inhibitor      CHEMBL5315124
# 1423            PI3-kinase p110-delta subunit inhibitor      CHEMBL5315125
# 1424                      Ergosterol sequestering agent      CHEMBL5465559
#
#      parent_molecule_chembl_id target_chembl_id  \
# 0                      CHEMBL3    CHEMBL1907589
# 1                      CHEMBL4    CHEMBL2311224
# 2                      CHEMBL5    CHEMBL2311224
# 3                      CHEMBL6    CHEMBL2094253
# 4                      CHEMBL8    CHEMBL2311224
# ...                        ...              ...
# 1420             CHEMBL4297588       CHEMBL2778
# 1421             CHEMBL1257073    CHEMBL5308522
# 1422                  CHEMBL33    CHEMBL2311225
# 1423             CHEMBL3039502       CHEMBL3130
# 1424             CHEMBL5465559    CHEMBL2364028
#
#                                     molecule_structures  \
# 0     {'canonical_smiles': 'CN1CCC[C@H]1c1cccnc1', '...
# 1     {'canonical_smiles': 'CC1COc2c(N3CCN(C)CC3)c(F...
# 2     {'canonical_smiles': 'CCn1cc(C(=O)O)c(=O)c2ccc...
# 3     {'canonical_smiles': 'COc1ccc2c(c1)c(CC(=O)O)c...
# 4     {'canonical_smiles': 'O=C(O)c1cn(C2CC2)c2cc(N3...
# ...                                                 ...
# 1420  {'canonical_smiles': 'CCCCC1(CCCC)CN(c2ccccc2)...
# 1421  {'canonical_smiles': 'O.O=C(NN1C(=O)[C@@H]2[C@...
# 1422  {'canonical_smiles': 'C[C@H]1COc2c(N3CCN(C)CC3...
# 1423  {'canonical_smiles': 'C[C@H](Nc1ncnc2nc[nH]c12...
# 1424                                               None
#
#                      pref_name  \
# 0                     NICOTINE
# 1                    OFLOXACIN
# 2               NALIDIXIC ACID
# 3                 INDOMETHACIN
# 4                CIPROFLOXACIN
# ...                        ...
# 1420  ODEVIXIBAT SESQUIHYDRATE
# 1421   TECOVIRIMAT MONOHYDRATE
# 1422              LEVOFLOXACIN
# 1423     DUVELISIB MONOHYDRATE
# 1424                  NYSTATIN
#
#                                        canonical_smiles
# 0                                  CN1CCC[C@H]1c1cccnc1
# 1      CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 2                       CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 3        COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1
# 4            O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O
# ...                                                 ...
# 1420  CCCCC1(CCCC)CN(c2ccccc2)c2cc(SC)c(OCC(=O)N[C@@...
# 1421  O.O=C(NN1C(=O)[C@@H]2[C@@H]3C=C[C@@H]([C@H]4C[...
# 1422  C[C@H]1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)...
# 1423  C[C@H](Nc1ncnc2nc[nH]c12)c1cc2cccc(Cl)c2c(=O)n...
# 1424                                                NaN
#
# [1422 rows x 11 columns]

# %% [markdown]
# # Identify whether there are any hepatotox or cardiotox alerts in the 'mito safe drugs' dataset

# %%
drug_warning = new_client.drug_warning
hepatotox_mol = drug_warning.filter(warning_class__icontains='hepato')
hepatotox_df = pd.DataFrame(hepatotox_mol)
hepatotox_df
# Out:
#           efo_id efo_id_for_warning_class                   efo_term  \
# 0           None              EFO:0011052                       None
# 1           None              EFO:0011052                       None
# 2           None              EFO:0011052                       None
# 3           None              EFO:0011052                       None
# 4           None              EFO:0011052                       None
# ..           ...                      ...                        ...
# 191  EFO:0004228              EFO:0011052  drug-induced liver injury
# 192         None              EFO:0011052                       None
# 193         None              EFO:0011052                       None
# 194         None              EFO:0011052                       None
# 195         None              EFO:0011052                       None
#
#     molecule_chembl_id parent_molecule_chembl_id   warning_class  \
# 0        CHEMBL4303288                CHEMBL1380  hepatotoxicity
# 1            CHEMBL112                 CHEMBL112  hepatotoxicity
# 2           CHEMBL1131                CHEMBL1131  hepatotoxicity
# 3            CHEMBL922                 CHEMBL922  hepatotoxicity
# 4            CHEMBL957                 CHEMBL957  hepatotoxicity
# ..                 ...                       ...             ...
# 191      CHEMBL1909288             CHEMBL1909288  hepatotoxicity
# 192           CHEMBL20                  CHEMBL20  hepatotoxicity
# 193      CHEMBL1201825             CHEMBL1201825  hepatotoxicity
# 194       CHEMBL295698              CHEMBL295698  hepatotoxicity
# 195      CHEMBL1743082             CHEMBL1743082  hepatotoxicity
#
#     warning_country warning_description  warning_id  \
# 0     United States                None           1
# 1     United States                None          17
# 2     United States                None          27
# 3     United States                None          36
# 4     United States                None         225
# ..              ...                 ...         ...
# 191       Australia      Hepatotoxicity        3708
# 192   United States                None        3724
# 193   United States                None        3758
# 194   United States                None        3807
# 195   United States                None        3838
#
#                                           warning_refs       warning_type  \
# 0    [{'ref_id': 'de109a2b-e36c-40d0-85fc-a67a9e7f1...  Black Box Warning
# 1    [{'ref_id': 'c5177abd-9465-40d8-861d-3904496d8...  Black Box Warning
# 2    [{'ref_id': '6af396c2-af3e-436d-ba9a-583637495...  Black Box Warning
# 3    [{'ref_id': 'e047f3b2-feae-4c5e-9d07-1fefb4c0e...  Black Box Warning
# 4    [{'ref_id': 'aceac005-5c16-41bf-9a5f-35ed4b2c1...  Black Box Warning
# ..                                                 ...                ...
# 191  [{'ref_id': '10.1177/009286150103500134', 'ref...          Withdrawn
# 192  [{'ref_id': '91dce113-7e16-4194-837e-d45719f8e...  Black Box Warning
# 193  [{'ref_id': '9c6d9e2a-9a77-4d11-b692-de87cfde3...  Black Box Warning
# 194                                                 []  Black Box Warning
# 195                                                 []  Black Box Warning
#
#      warning_year
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 191        1971.0
# 192           NaN
# 193           NaN
# 194           NaN
# 195           NaN
#
# [196 rows x 12 columns]

# %%
drug_warning = new_client.drug_warning
cardiotox_mol = drug_warning.filter(warning_class__icontains='cardio')
cardiotox_df = pd.DataFrame(cardiotox_mol)
cardiotox_df
# Out:
#     efo_id efo_id_for_warning_class efo_term molecule_chembl_id  \
# 0     None              EFO:1001482     None       CHEMBL270190
# 1     None              EFO:1001482     None      CHEMBL1083993
# 2     None              EFO:1001482     None          CHEMBL501
# 3     None              EFO:1001482     None               None
# 4     None              EFO:1001482     None           CHEMBL24
# ..     ...                      ...      ...                ...
# 169   None              EFO:1001482     None      CHEMBL2364649
# 170   None              EFO:1001482     None      CHEMBL4802239
# 171   None              EFO:1001482     None       CHEMBL295698
# 172   None              EFO:1001482     None      CHEMBL4297517
# 173   None              EFO:1001482     None      CHEMBL1743082
#
#     parent_molecule_chembl_id   warning_class warning_country  \
# 0                CHEMBL270190  cardiotoxicity   United States
# 1                   CHEMBL633  cardiotoxicity   United States
# 2                   CHEMBL405  cardiotoxicity   United States
# 3                        None  cardiotoxicity   United States
# 4                    CHEMBL24  cardiotoxicity   United States
# ..                        ...             ...             ...
# 169             CHEMBL2364649  cardiotoxicity   United States
# 170             CHEMBL4650319  cardiotoxicity   United States
# 171              CHEMBL295698  cardiotoxicity   United States
# 172             CHEMBL4297517  cardiotoxicity   United States
# 173             CHEMBL1743082  cardiotoxicity   United States
#
#     warning_description  warning_id  \
# 0                  None          81
# 1                  None          98
# 2                  None         109
# 3                  None         135
# 4                  None         145
# ..                  ...         ...
# 169                None        3746
# 170                None        3784
# 171                None        3806
# 172                None        3813
# 173                None        3839
#
#                                           warning_refs       warning_type  \
# 0    [{'ref_id': '77a67dc6-35d3-48ff-9d18-292d4d442...  Black Box Warning
# 1    [{'ref_id': '730039c2-0a32-4775-855d-98b2207e9...  Black Box Warning
# 2    [{'ref_id': 'f469fb38-0380-4621-9db3-a4f429126...  Black Box Warning
# 3    [{'ref_id': 'a482eccd-8837-47ea-904d-2f2c294d1...  Black Box Warning
# 4    [{'ref_id': '06c0a04f-a77e-4871-9bb4-13abe2cbb...  Black Box Warning
# ..                                                 ...                ...
# 169  [{'ref_id': 'e97a5872-eabf-463b-8f4c-5b5aed9c7...  Black Box Warning
# 170  [{'ref_id': 'f1a91500-a944-4cb8-b4a8-ae278bcf7...  Black Box Warning
# 171                                                 []  Black Box Warning
# 172                                                 []  Black Box Warning
# 173                                                 []  Black Box Warning
#
#      warning_year
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 169           NaN
# 170           NaN
# 171           NaN
# 172           NaN
# 173           NaN
#
# [174 rows x 12 columns]

# %%
mito_safe_drugs_id = mito_safe_drugs["molecule_chembl_id"].tolist()
print(len(mito_safe_drugs_id))

hepatotox_id = hepatotox_df["molecule_chembl_id"].tolist()
print(len(hepatotox_id))

cardiotox_id = cardiotox_df["molecule_chembl_id"].tolist()
print(len(cardiotox_id))
# Out:
# 1422
# 196
# 174

# %%
mito_safe_drugs_cross_hepatotox = list(set(mito_safe_drugs_id) & set(hepatotox_id))
print(len(mito_safe_drugs_cross_hepatotox))

mito_safe_drugs_cross_cardiotox = list(set(mito_safe_drugs_id) & set(cardiotox_id))
print(len(mito_safe_drugs_cross_cardiotox))

hepatotox_cross_cardiotox = list(set(cardiotox_id) & set(hepatotox_id))
print(len(hepatotox_cross_cardiotox))
# Out:
# 56
# 84
# 6

# %%
mito_safe_drugs_hepatotox_filt = mito_safe_drugs[~mito_safe_drugs['molecule_chembl_id'].isin(hepatotox_id)]
len(mito_safe_drugs_hepatotox_filt)
# Out:
# 1366

# %%
mito_safe_drugs_hepato_cardio_tox_filt = mito_safe_drugs_hepatotox_filt[~mito_safe_drugs_hepatotox_filt['molecule_chembl_id'].isin(cardiotox_id)]
len(mito_safe_drugs_hepato_cardio_tox_filt)
# Out:
# 1287

# %%
#mito_safe_drugs_hepato_cardio_tox_filt.to_csv("../AL00_datasets/chembl_mito_safe_drugs_cardio_hepato_alerts_removed.csv", index=False)
